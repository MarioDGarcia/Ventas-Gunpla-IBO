# %% [markdown]
# #  ***Limpieza de datos para gunpla***
# ### *Creado por: Mario Daniel Ortega García*

# %% [markdown]
# ## **Limpiando ID's (primera parte)**

# %%
import pandas as pd

# %%
df = pd.read_csv("Ventas_gunplas_sucias.csv")
df.head()
# Out:
#    id_venta fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Pais
# 0       1.0  2024-08-29         36.0      IO     14.0         NaN      NaN
# 1       2.0  2023-07-24         25.0      TJ     17.0         NaN      NaN
# 2       3.0  2022-09-23          7.0      IQ      5.0         NaN      NaN
# 3       4.0  2023-08-19         11.0      CY     17.0         NaN      NaN
# 4       5.0  2022-07-18         31.0      AZ     10.0         NaN      NaN

# %%
df.tail()
# Out:
#         id_venta fecha_venta  id_producto id_pais unidades Fecha_venta  \
# 100995   59350.0  2022-09-18         46.0      PK     11.0         NaN
# 100996   66594.0  2022-12-25         60.0      IO     14.0         NaN
# 100997   88077.0  2022-07-30         26.0      SA      4.0         NaN
# 100998   58895.0  2024-03-13         16.0      MN     17.0         NaN
# 100999   99169.0  2023-08-02         32.0      PK      4.0         NaN
#
#         Id_Pais
# 100995      NaN
# 100996      NaN
# 100997      NaN
# 100998      NaN
# 100999      NaN

# %%
df["Id_Venta"] = df.index
df.head()
# Out:
#    id_venta fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Pais  \
# 0       1.0  2024-08-29         36.0      IO     14.0         NaN      NaN
# 1       2.0  2023-07-24         25.0      TJ     17.0         NaN      NaN
# 2       3.0  2022-09-23          7.0      IQ      5.0         NaN      NaN
# 3       4.0  2023-08-19         11.0      CY     17.0         NaN      NaN
# 4       5.0  2022-07-18         31.0      AZ     10.0         NaN      NaN
#
#    Id_Venta
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4

# %%
del df["id_venta"]
df.head()
# Out:
#   fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Pais  Id_Venta
# 0  2024-08-29         36.0      IO     14.0         NaN      NaN         0
# 1  2023-07-24         25.0      TJ     17.0         NaN      NaN         1
# 2  2022-09-23          7.0      IQ      5.0         NaN      NaN         2
# 3  2023-08-19         11.0      CY     17.0         NaN      NaN         3
# 4  2022-07-18         31.0      AZ     10.0         NaN      NaN         4

# %% [markdown]
# ### ***Limpiando id de prodcutos***

# %%
productos = pd.read_csv("IBO_Gunplas.csv")
productos.head()
# Out:
#    Id_Nuevo             nombreProducto escala  grado  precioUSD
# 0         0            Gundam Barbatos  1/144      1      13.00
# 1         1      Graze (Std/Commander)  1/144      1      13.00
# 2         2  Schwalbe Graze (McGillis)  1/144      1      15.00
# 3         3                  Graze Kai  1/144      1      16.95
# 4         4                    Hyakuri  1/144      1      12.95

# %%
productos.describe()
# Out:
#         Id_Nuevo      grado  precioUSD
# count  66.000000  66.000000  66.000000
# mean   32.500000   2.590909  18.984848
# std    19.196354   2.443058  10.935886
# min     0.000000   1.000000   6.200000
# 25%    16.250000   1.000000  12.962500
# 50%    32.500000   1.000000  16.950000
# 75%    48.750000   5.000000  18.950000
# max    65.000000   7.000000  67.000000

# %%
df = df[df["id_producto"] <= 65] ## se puede realizar un join/merge entre ambos archivos y
                                # que se haga autoamtico, pero este es otro metodo

# %%
df[df["id_producto"]>64] ## comprobamos si esta el ultimo producto (el 65)
# Out:
#        fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Pais  \
# 37      2022-04-03         65.0      TR      3.0         NaN      NaN
# 48      2024-08-28         65.0      SA      6.0         NaN      NaN
# 135     2023-01-08         65.0      PH     15.0         NaN      NaN
# 146     2022-01-30         65.0      BN     17.0         NaN      NaN
# 312     2022-09-15         65.0      BH      9.0         NaN      NaN
# ...            ...          ...     ...      ...         ...      ...
# 100772  2022-12-24         65.0      KG      5.0         NaN      NaN
# 100814  2023-05-11         65.0      SY      2.0         NaN      NaN
# 100831  2022-04-26         65.0      CN      1.0         NaN      NaN
# 100843  2022-07-08         65.0      UZ      7.0         NaN      NaN
# 100901  2022-07-26         65.0      GE     16.0         NaN      NaN
#
#         Id_Venta
# 37            37
# 48            48
# 135          135
# 146          146
# 312          312
# ...

# %% [markdown]
# ## **Cambiar a int el id Prodcuto**

# %%
df["id_producto"] = df["id_producto"].astype(int)
df.head()
# Out:
#   fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Pais  Id_Venta
# 0  2024-08-29           36      IO     14.0         NaN      NaN         0
# 1  2023-07-24           25      TJ     17.0         NaN      NaN         1
# 2  2022-09-23            7      IQ      5.0         NaN      NaN         2
# 3  2023-08-19           11      CY     17.0         NaN      NaN         3
# 4  2022-07-18           31      AZ     10.0         NaN      NaN         4

# %% [markdown]
# ## **Eliminar Columnas NaN**

# %%
del df["Id_Pais"]
df
# Out:
#        fecha_venta  id_producto id_pais unidades Fecha_venta  Id_Venta
# 0       2024-08-29           36      IO     14.0         NaN         0
# 1       2023-07-24           25      TJ     17.0         NaN         1
# 2       2022-09-23            7      IQ      5.0         NaN         2
# 3       2023-08-19           11      CY     17.0         NaN         3
# 4       2022-07-18           31      AZ     10.0         NaN         4
# ...            ...          ...     ...      ...         ...       ...
# 100995  2022-09-18           46      PK     11.0         NaN    100995
# 100996  2022-12-25           60      IO     14.0         NaN    100996
# 100997  2022-07-30           26      SA      4.0         NaN    100997
# 100998  2024-03-13           16      MN     17.0         NaN    100998
# 100999  2023-08-02           32      PK      4.0         NaN    100999
#
# [99490 rows x 6 columns]

# %%
del df["Fecha_venta"]
df
# Out:
#        fecha_venta  id_producto id_pais unidades  Id_Venta
# 0       2024-08-29           36      IO     14.0         0
# 1       2023-07-24           25      TJ     17.0         1
# 2       2022-09-23            7      IQ      5.0         2
# 3       2023-08-19           11      CY     17.0         3
# 4       2022-07-18           31      AZ     10.0         4
# ...            ...          ...     ...      ...       ...
# 100995  2022-09-18           46      PK     11.0    100995
# 100996  2022-12-25           60      IO     14.0    100996
# 100997  2022-07-30           26      SA      4.0    100997
# 100998  2024-03-13           16      MN     17.0    100998
# 100999  2023-08-02           32      PK      4.0    100999
#
# [99490 rows x 5 columns]

# %% [markdown]
# ## **ID PAIS**

# %%
paises = pd.read_csv("Paises con continene.csv")
paises
# Out:
#     id_pais            nombrePais continente
# 0        AD               Andorra     Europa
# 1        AE  United Arab Emirates       Asia
# 2        AF           Afghanistan       Asia
# 3        AG   Antigua and Barbuda     Caribe
# 4        AI              Anguilla     Caribe
# ..      ...                   ...        ...
# 197      WS                 Samoa    Oceanía
# 198      YE                 Yemen       Asia
# 199      ZA          South Africa     África
# 200      ZM                Zambia     África
# 201      ZW              Zimbabwe     África
#
# [202 rows x 3 columns]

# %%
listaPaisesCodigo = paises["id_pais"].unique().tolist() ## otra forma seria el join/merge
listaPaisesCodigo
# Out:
# ['AD',
#  'AE',
#  'AF',
#  'AG',
#  'AI',
#  'AL',
#  'AM',
#  'AO',
#  'AQ',
#  'AR',
#  'AS',
#  'AT',
#  'AU',
#  'AW',
#  'AZ',
#  'BA',
#  'BB',
#  'BD',
#  'BE',
#  'BF',
#  'BG',
#  'BH',
#  'BI',
#  'BJ',
#  'BM',
#  'BN',
#  'BO',
#  'BR',
#  'BS',
#  'BT',
#  'BW',
#  'BY',
#  'BZ',
#  'CA',
#  'CD',
#  'CF',
#  'CG',
#  'CH',
#  'CI',
#  'CL',
#  'CM',
#  'CN',
#  'CO',
#  'CR',
#  'CU',
#  'CV',
#  'CY',
#  'CZ',
#  'DE',
#  'DJ',
#  'DK',
#  'DM',
#  'DO',
#  'DZ',
#  'EC',
#  'EE',
#  'EG',
#  'EH',
#  'ER',
#  'ES',
#  'ET',
#  'FI',
#  'FJ',
#  'FM',
#  'FR',
#  'GA',
#  'GB',
#  'GD',
#  'GE',
#  'GF',
#  'GH',
#  'GI',
#  'GL',
#  'GM',
#  'GN',
#  'GQ',
#  'GR',
#  'GT',
#  'GW',
#  'GY',
#  'HN',
#  'HR',
#  'HT',
#  'HU',
#  'ID',
#  'IE',
#  'IL',
#  'IN',
#  'IQ',
#  'IR',
#  'IS',
#  'IT',
#  'JM',
#  'JO',
#  'JP',
#  'KE',
#  'KG',
#  'KH',
#  'KI',
#  'KM',
#  'KN',
#  'KP',
#  'KR',
#  'KW',
#  'KZ',
#  'LA',
#  'LB',
#  'LC',
#  'LI',
#  'LK',
#  'LR',
# ...

# %%
df = df[df["id_pais"].isin(listaPaisesCodigo)]

# %%
df
# Out:
#        fecha_venta  id_producto id_pais unidades  Id_Venta
# 1       2023-07-24           25      TJ     17.0         1
# 2       2022-09-23            7      IQ      5.0         2
# 3       2023-08-19           11      CY     17.0         3
# 4       2022-07-18           31      AZ     10.0         4
# 5       2023-10-28            6      OM      1.0         5
# ...            ...          ...     ...      ...       ...
# 100994  2024-11-09           55      IN      3.0    100994
# 100995  2022-09-18           46      PK     11.0    100995
# 100997  2022-07-30           26      SA      4.0    100997
# 100998  2024-03-13           16      MN     17.0    100998
# 100999  2023-08-02           32      PK      4.0    100999
#
# [89710 rows x 5 columns]

# %% [markdown]
# ## **Unidades**
# En este apartado existen cadenas de texto como "muchas" en lugar de un numero, asi que vamos a convertir todo a numero

# %%
df['unidades_limpio'] = df['unidades'].str.extract('(\d+)') 
# con expresion regular extraemos solo el numero si es que hay mezcla (2 unidades, 22 piezas, etc)


df['unidades_limpio'] = pd.to_numeric(df['unidades_limpio'], errors='coerce')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\3739141694.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['unidades_limpio'] = df['unidades'].str.extract('(\d+)')
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\3739141694.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['unidades_limpio'] = df['unidades'].str.extract('(\d+)')
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\3739141694.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## **Eliminar Nulos**

# %%
df = df.dropna()

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [fecha_venta, id_producto, id_pais, unidades, Id_Venta, unidades_limpio]
# Index: []

# %%
del df["unidades"]

# %%
df["unidades_limpio"] = df["unidades_limpio"].astype(int)
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\955543930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["unidades_limpio"] = df["unidades_limpio"].astype(int)

# %% [markdown]
# ## **Dar Id de Venta**

# %%
del df["Id_Venta"]

# %%
df['Id_venta'] = range(1, len(df) + 1)
df
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\1970734135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Id_venta'] = range(1, len(df) + 1)
#        fecha_venta  id_producto id_pais  unidades_limpio  Id_venta
# 1       2023-07-24           25      TJ               17         1
# 2       2022-09-23            7      IQ                5         2
# 3       2023-08-19           11      CY               17         3
# 4       2022-07-18           31      AZ               10         4
# 5       2023-10-28            6      OM                1         5
# ...            ...          ...     ...              ...       ...
# 100994  2024-11-09           55      IN                3     87927
# ...

# %%
df.index = df["Id_venta"]
df
# Out:
#          fecha_venta  id_producto id_pais  unidades_limpio  Id_venta
# Id_venta
# 1         2023-07-24           25      TJ               17         1
# 2         2022-09-23            7      IQ                5         2
# 3         2023-08-19           11      CY               17         3
# 4         2022-07-18           31      AZ               10         4
# 5         2023-10-28            6      OM                1         5
# ...              ...          ...     ...              ...       ...
# 87927     2024-11-09           55      IN                3     87927
# 87928     2022-09-18           46      PK               11     87928
# 87929     2022-07-30           26      SA                4     87929
# 87930     2024-03-13           16      MN               17     87930
# 87931     2023-08-02           32      PK                4     87931
#
# [87931 rows x 5 columns]

# %%
df['fecha_venta'] = pd.to_datetime(df['fecha_venta'], errors='coerce', dayfirst=False)
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\1865403494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fecha_venta'] = pd.to_datetime(df['fecha_venta'], errors='coerce', dayfirst=False)

# %%
del df["Id_venta"]

# %%
df.rename(columns={'unidades_limpio': 'unidades'}, inplace=True)
# Out:
# C:\Users\mario\AppData\Local\Temp\ipykernel_28788\3940289575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'unidades_limpio': 'unidades'}, inplace=True)

# %%
df.to_csv("Ventas_IBO_Gunpla_V2.0.csv") ## V2.0 porque es la segunda vez que se realizaba esta pequeña practica

# %% [markdown]
# ## Limpieza de Datos
#
# Tras el proceso de depuración, contamos con un conjunto de datos **limpio** y listo para su análisis.
#
# No obstante, en fases posteriores se añadirá un mayor **realismo** al dataset, ajustando especialmente la distribución geográfica y la procedencia de las ventas de estos Gunplas, con el fin de reflejar patrones más cercanos a un escenario real.
#
# ---
#
# ## Próximos Pasos
#
# - **Continuar con el Dashboard** → ver sección *"3. Dashboard"*
# - **Aumentar el realismo de los datos** → ver sección *"2.5. Realismo a los datos"*
